# %% [markdown]
# <a href="https://colab.research.google.com/github/EYBishal/Python-Training-Bootcamp/blob/main/22nd-Dec-2025/avro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Exercise").getOrCreate()

# %%
data = [
    ("ORD001","Delhi","Laptop",45000,"2024-01-05"),
    ("ORD002","Mumbai","Mobile",32000,"2024-01-06"),
    ("ORD003","Bangalore","Tablet",30000,"2024-01-07"),
    ("ORD004","Delhi","Laptop",55000,"2024-01-08"),
    ("ORD005","Mumbai","Tablet",34000,"2024-01-09")
]
column=["iorder_id","city","product","price","date"]
df=spark.createDataFrame(data,column)
df.show()
# Out:
# +---------+---------+-------+-----+----------+
# |iorder_id|     city|product|price|      date|
# +---------+---------+-------+-----+----------+
# |   ORD001|    Delhi| Laptop|45000|2024-01-05|
# |   ORD002|   Mumbai| Mobile|32000|2024-01-06|
# |   ORD003|Bangalore| Tablet|30000|2024-01-07|
# |   ORD004|    Delhi| Laptop|55000|2024-01-08|
# |   ORD005|   Mumbai| Tablet|34000|2024-01-09|
# +---------+---------+-------+-----+----------+

# %% [markdown]
# **REQUIRED WHEN WE DO HEAVY COMPRESSION , LIKE TELECOM DATA**

# %%
df.write.mode("overwrite").avro("data/avro/orders")

# %%
# !pip uninstall -y pyspark
# !pip install pyspark==3.5.1
# Out:
# Found existing installation: pyspark 4.0.1
# Uninstalling pyspark-4.0.1:
#   Successfully uninstalled pyspark-4.0.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 4.9 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=14c23afb015a628a65ce1e91e8402fa809b84962894f83991fe5a5011de3a6ad
#   Stored in directory: /root/.cache/pip/wheels/b1/91/5f/283b53010a8016a4ff1c4a1edd99bbe73afacb099645b5471b
# Successfully built pyspark

# %%
df_p=spark.read.avro("data/avro/orders")
df_p.show()
# Out:
# +---------+---------+-------+-----+----------+
# |iorder_id|     city|product|price|      date|
# +---------+---------+-------+-----+----------+
# |   ORD003|Bangalore| Tablet|30000|2024-01-07|
# |   ORD004|    Delhi| Laptop|55000|2024-01-08|
# |   ORD005|   Mumbai| Tablet|34000|2024-01-09|
# |   ORD001|    Delhi| Laptop|45000|2024-01-05|
# |   ORD002|   Mumbai| Mobile|32000|2024-01-06|
# +---------+---------+-------+-----+----------+
